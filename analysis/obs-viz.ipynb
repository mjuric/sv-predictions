# %% [markdown]
# # Visualization of the science validation survey
#
# For this notebook to work, please download the data files in the `../data` directory. Look at the README.md file for instructions on how to download them.
#
# The final movie result from this directory will be in `../results` directory

# %%
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import astropy
from astropy.time import Time
from astropy.coordinates import solar_system_ephemeris

# %%
# Science Validation survey visualization

conn = sqlite3.connect('../data/sv_20250729.db')

df = pd.read_sql_query('SELECT * FROM observations WHERE observationId > 100000 ORDER BY observationId', conn)

# %%
df.columns.values
# Out:
# array(['observationId', 'exposure_name', 'controller', 'day_obs',
#        'seq_num', 'physical_filter', 'band', 'fieldRA', 'fieldDec',
#        'rotSkyPos', 'azimuth_start', 'azimuth_end', 'azimuth',
#        'altitude_start', 'altitude_end', 'altitude',
#        'zenith_distance_start', 'zenith_distance_end', 'zenith_distance',
#        'airmass', 'exp_midpt', 'exp_midpt_mjd', 'obs_start',
#        'observationStartMJD', 'obs_end', 'obs_end_mjd',
#        'visitExposureTime', 'shut_time', 'visitTime', 'group_id',
#        'cur_index', 'max_index', 'img_type', 'emulated',
#        'science_program', 'observation_reason', 'target_name', 'air_temp',
#        'pressure', 'humidity', 'wind_speed', 'wind_dir', 'dimm_seeing',
#        'focus_z', 'simulated', 'vignette', 'vignette_min',
#        'scheduler_note', 's_region', 'can_see_sky', 'n_inputs',
#        'pixel_scale_min', 'pixel_scale_max', 'pixel_scale_median',
#        'astrom_offset_mean_min', 'astrom_offset_mean_max',
#        'astrom_offset_mean_median', 'astrom_offset_std_min',
#        'astrom_offset_std_max', 'astrom_offset_std_median',
#        'eff_time_min', 'eff_time_max', 'eff_time_median',
#        'eff_time_psf_sigma_scale_min', 'eff_time_psf_sigma_scale_max',
#        'eff_time_psf_sigma_scale_median', 'eff_time_sky_bg_scale_min',
#        'eff_time_sky_bg_scale_max', 'eff_time_sky_bg_scale_median',
#        'eff_time_zero_point_scale_min', 'eff_time_zero_point_scale_max',
#        'eff_time_zero_point_scale_median', 'stats_mag_lim_min',
#        'stats_mag_lim_max', 'stats_mag_lim_median',
#        'psf_ap_flux_delta_min', 'psf_ap_flux_delta_max',
#        'psf_ap_flux_delta_median', 'psf_ap_corr_sigma_scaled_delta_min',
#        'psf_ap_corr_sigma_scaled_delta_max',
#        'psf_ap_corr_sigma_scaled_delta_median',
#        'max_dist_to_nearest_psf_min', 'max_dist_to_nearest_psf_max',
#        'max_dist_to_nearest_psf_median', 'mean_var_min', 'mean_var_max',
#        'mean_var_median', 'n_psf_star_min', 'n_psf_star_max',
#        'n_psf_star_median', 'n_psf_star_total', 'psf_area_min',
#        'psf_area_max', 'psf_area_median', 'psf_ixx_min', 'psf_ixx_max',
#        'psf_ixx_median', 'psf_ixy_min', 'psf_ixy_max', 'psf_ixy_median',
#        'psf_iyy_min', 'psf_iyy_max', 'psf_iyy_median', 'psf_sigma_min',
#        'psf_sigma_max', 'psf_sigma_median',
#        'psf_star_delta_e1_median_min', 'psf_star_delta_e1_median_max',
#        'psf_star_delta_e1_median_median', 'psf_star_delta_e1_scatter_min',
#        'psf_star_delta_e1_scatter_max',
#        'psf_star_delta_e1_scatter_median', 'psf_star_delta_e2_median_min',
#        'psf_star_delta_e2_median_max', 'psf_star_delta_e2_median_median',
#        'psf_star_delta_e2_scatter_min', 'psf_star_delta_e2_scatter_max',
#        'psf_star_delta_e2_scatter_median',
#        'psf_star_delta_size_median_min', 'psf_star_delta_size_median_max',
#        'psf_star_delta_size_median_median',
#        'psf_star_delta_size_scatter_min',
#        'psf_star_delta_size_scatter_max',
#        'psf_star_delta_size_scatter_median',
#        'psf_star_scaled_delta_size_scatter_min',
#        'psf_star_scaled_delta_size_scatter_max',
#        'psf_star_scaled_delta_size_scatter_median',
#        'psf_trace_radius_delta_min', 'psf_trace_radius_delta_max',
#        'psf_trace_radius_delta_median', 'sky_bg_min', 'sky_bg_max',
#        'sky_bg_median', 'sky_noise_min', 'sky_noise_max',
#        'sky_noise_median', 'seeing_zenith_500nm_min',
#        'seeing_zenith_500nm_max', 'seeing_zenith_500nm_median',
#        'zero_point_min', 'zero_point_max', 'zero_point_median',
#        'low_snr_source_count_min', 'low_snr_source_count_max',
#        'low_snr_source_count_median', 'low_snr_source_count_total',
#        'high_snr_source_count_min', 'high_snr_source_count_max',
#        'high_snr_source_count_median', 'high_snr_source_count_total',
#        'z4', 'z5', 'z6', 'z7', 'z8', 'z9', 'z10', 'z11', 'z12', 'z13',
#        'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z20', 'z21', 'z22',
#        'z23', 'z24', 'z25', 'z26', 'z27', 'z28', 'ringss_seeing',
#        'aos_fwhm', 'donut_blur_fwhm', 'physical_rotator_angle',
#        'prev_obs_start_mjd', 'prev_obs_end_mjd', 'slewTime', 'eclip_lat',
#        'eclip_lon', 'gal_lat', 'gal_lon', 'seeingFwhmEff',
#        'seeingFwhmGeom', 'FWHM_500', 'lst', 'HA', 'approx_pa',
#        'approx_rotTelPos', 'moon_alt', 'moon_az', 'moon_RA', 'moon_Dec',
#        'moon_distance', 'moonPhase', 'zero_point_1s',
#        'zero_point_1s_pred', 'cloud_extinction', 'skyBrightness',
#        'fiveSigmaDepth', 'nexp', 'night', 'note', 'flush_by_mjd',
#        'filter', 'rotSkyPos_desired', 'numExposures', 'seeingFwhm500',
#        'slewDistance', 'paraAngle', 'pseudoParaAngle', 'cloud', 'moonAlt',
#        'sunAlt', 'target_id', 'observationStartLST', 'rotTelPos',
#        'rotTelPos_backup', 'moonAz', 'sunAz', 'sunRA', 'sunDec', 'moonRA',
#        'moonDec', 'moonDistance', 'solarElong', 'cummTelAz'], dtype=object)

# %%
df['simulated']
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 12179    None
# 12180    None
# 12181    None
# 12182    None
# 12183    None
# Name: simulated, Length: 12184, dtype: object

# %%
df
# Out:
#        observationId         exposure_name controller     day_obs  seq_num  \
# 0      2025062000248  MC_O_20250620_000248          O  20250620.0    248.0
# 1      2025062000249  MC_O_20250620_000249          O  20250620.0    249.0
# 2      2025062000250  MC_O_20250620_000250          O  20250620.0    250.0
# 3      2025062000251  MC_O_20250620_000251          O  20250620.0    251.0
# 4      2025062000252  MC_O_20250620_000252          O  20250620.0    252.0
# ...              ...                   ...        ...         ...      ...
# 12179  2025072800511  MC_O_20250728_000511          O  20250728.0    511.0
# 12180  2025072800512  MC_O_20250728_000512          O  20250728.0    512.0
# 12181  2025072800513  MC_O_20250728_000513          O  20250728.0    513.0
# 12182  2025072800514  MC_O_20250728_000514          O  20250728.0    514.0
# 12183  2025072800515  MC_O_20250728_000515          O  20250728.0    515.0
#
#       physical_filter band     fieldRA   fieldDec   rotSkyPos  ...  \
# 0                i_39    i  259.031417 -16.841287  124.088653  ...
# 1                i_39    i  255.235319 -13.581529  109.375195  ...
# 2                i_39    i  252.234921 -13.082034  100.507091  ...
# 3                i_39    i  249.206911 -12.511995   91.779497  ...
# 4                i_39    i  246.144506 -11.839659   83.714383  ...
# ...               ...  ...         ...        ...         ...  ...
# 12179            r_57    r  341.996722 -17.650111   56.204816  ...
# 12180            r_57    r  338.942174 -16.357752   56.690762  ...
# 12181            r_57    r  336.281278 -17.816949   54.187651  ...
# 12182            r_57    r  333.139608 -13.288483   58.017399  ...
# 12183            r_57    r  332.936367 -10.261742   60.654161  ...
#
#        rotTelPos_backup  moonAz  sunAz  sunRA  sunDec  moonRA  moonDec  \
# 0                  None    None   None   None    None    None     None
# 1                  None    None   None   None    None    None     None
# 2                  None    None   None   None    None    None     None
# 3                  None    None   None   None    None    None     None
# 4                  None    None   None   None    None    None     None
# ...                 ...     ...    ...    ...     ...     ...      ...
# 12179              None    None   None   None    None    None     None
# 12180              None    None   None   None    None    None     None
# 12181              None    None   None   None    None    None     None
# 12182              None    None   None   None    None    None     None
# 12183              None    None   None   None    None    None     None
#
#        moonDistance  solarElong  cummTelAz
# 0              None        None       None
# 1              None        None       None
# 2              None        None       None
# 3              None        None       None
# 4              None        None       None
# ...             ...         ...        ...
# 12179          None        None       None
# 12180          None        None       None
# 12181          None        None       None
# 12182          None        None       None
# 12183          None        None       None
#
# [12184 rows x 231 columns]

# %%
ra = df['fieldRA'].values
mask = ra>180
ra[mask] = ra[mask]-360
df['RA'] = -np.deg2rad(ra)

# %%
df['Dec'] = np.deg2rad(df['fieldDec'])

# %%
from astropy.time import Time

# %%
directory = Path("../results/sv-viz")
directory.mkdir(parents=True, exist_ok=True)

# %%
! rm -f ../results/sv-viz/*.png

t=0
n_obs_in_frame = 10
frame_num=0
while t < len(df):
    fig = plt.figure()
    ax = fig.add_subplot(111,projection='mollweide')
    t_obs = df.loc[t, 'observationStartMJD']
    tim = Time(t_obs, format='mjd')
    utc = tim.to_datetime()
    ax.set_title(f'Time: {utc}')
    night = df.query(f'observationStartMJD <= {t_obs}')
    current_discoveries_plot = df.query(f'observationStartMJD < {t_obs}')
    current_discoveries_plot.plot.scatter('RA','Dec',ax=ax, c='gray', alpha=0.05)
    
    time = Time(df.loc[t, 'observationStartMJD'], format='mjd')
    print(time)
    sun = astropy.coordinates.get_body(body='sun', time=time)
    moon = astropy.coordinates.get_body(body='moon', time=time)
    print(sun)
    print(moon)
    
#    obs = df.query(f'observationId >= {t} & observationId < {t+n_obs_in_frame}')
    obs = df.iloc[t:t+n_obs_in_frame]
    
    u_obs = obs[obs['band'] == 'u']
    g_obs = obs[obs['band'] == 'g']
    r_obs = obs[obs['band'] == 'r']
    i_obs = obs[obs['band'] == 'i']
    z_obs = obs[obs['band'] == 'z']
    y_obs = obs[obs['band'] == 'y']
    
    u_obs.plot.scatter('RA','Dec',ax=ax, c='blue', label='u filter',alpha=0.5)
    g_obs.plot.scatter('RA','Dec',ax=ax, c='cyan', label='g filter',alpha=0.5)
    r_obs.plot.scatter('RA','Dec',ax=ax, c='green', label='r filter',alpha=0.5)
    i_obs.plot.scatter('RA','Dec',ax=ax, c='yellow', label='i filter',alpha=0.5)
    z_obs.plot.scatter('RA','Dec',ax=ax, c='red', label='z filter',alpha=0.5)
    y_obs.plot.scatter('RA','Dec',ax=ax, c='purple', label='y filter',alpha=0.5)

    ax.set_xticklabels(['150°','120°','90°','60°','30°','0°','-30°','-60°','-90°','-120°','-150°'])

    sun_ra = sun.ra.degree
    if sun_ra>180:
        sun_ra-=360

    moon_ra = moon.ra.degree
    if moon_ra>180:
        moon_ra-=360

    ax.scatter(-np.deg2rad(sun_ra),np.deg2rad(sun.dec.degree),c='y',edgecolor='k',s=40)
    ax.scatter(-np.deg2rad(moon_ra),np.deg2rad(moon.dec.degree),c='gray',edgecolor='k',s=40)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, frameon=False)
    fig.savefig(f'../results/sv-viz/frame_{frame_num:05d}.png')
    plt.close()
    
    frame_num+=1
    t+=n_obs_in_frame
# Out:
# 60847.14660269778
# <SkyCoord (GCRS: obstime=60847.14660269778, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.64691205, 23.43557576, 1.01620657)>
# <SkyCoord (GCRS: obstime=60847.14660269778, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (27.37623048, 14.64635507, 0.00244529)>
# 60847.151693167834
# <SkyCoord (GCRS: obstime=60847.151693167834, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.65220797, 23.43558775, 1.01620693)>
# <SkyCoord (GCRS: obstime=60847.151693167834, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (27.44560389, 14.67711796, 0.0024452)>
# 60847.15749001952
# <SkyCoord (GCRS: obstime=60847.15749001952, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.65823878, 23.43560119, 1.01620735)>
# <SkyCoord (GCRS: obstime=60847.15749001952, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (27.52463407, 14.71212734, 0.00244511)>
# 60847.16215360938
# <SkyCoord (GCRS: obstime=60847.16215360938, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.66309059, 23.43561183, 1.01620768)>
# <SkyCoord (GCRS: obstime=60847.16215360938, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (27.58823748, 14.74027521, 0.00244503)>
# 60847.16888272961
# <SkyCoord (GCRS: obstime=60847.16888272961, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.6700913, 23.43562692, 1.01620816)>
# <SkyCoord (GCRS: obstime=60847.16888272961, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (27.68004791, 14.7808626, 0.00244493)>
# 60847.17468489551
# <SkyCoord (GCRS: obstime=60847.17468489551, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.67612764, 23.43563968, 1.01620858)>
# <SkyCoord (GCRS: obstime=60847.17468489551, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (27
obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.75634161, 23.43578722, 1.01621409)>
# <SkyCoord (GCRS: obstime=60847.25178712234, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (28.81475978, 15.27820876, 0.00244361)>
# 60847.25636305421
# <SkyCoord (GCRS: obstime=60847.25636305421, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.76110221, 23.43579468, 1.01621442)>
# <SkyCoord (GCRS: obstime=60847.25636305421, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (28.87758513, 15.30551161, 0.00244354)>
# 60847.26261181541
# <SkyCoord (GCRS: obstime=60847.26261181541, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.76760316, 23.43580465, 1.01621486)>
# <SkyCoord (GCRS: obstime=60847.26261181541, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (28.96341073, 15.34277007, 0.00244345)>
# 60847.26740756495
# <SkyCoord (GCRS: obstime=60847.26740756495, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.77259245, 23.43581211, 1.0162152)>
# <SkyCoord (GCRS: obstime=60847.26740756495, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.02930545, 15.37134483, 0.00244337)>
# 60847.27222827681
# <SkyCoord (GCRS: obstime=60847.27222827681, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.77760772, 23.43581945, 1.01621555)>
# <SkyCoord (GCRS: obstime=60847.27222827681, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.09556591, 15.40005071, 0.0024433)>
# 60847.27687745324
# <SkyCoord (GCRS: obstime=60847.27687745324, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.78244452, 23.43582638, 1.01621588)>
# <SkyCoord (GCRS: obstime=60847.27687745324, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.15949026, 15.42771837, 0.00244323)>
# 60847.282996444286
# <SkyCoord (GCRS: obstime=60847.282996444286, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.78881046, 23.43583527, 1.01621631)>
# <SkyCoord (GCRS: obstime=60847.282996444286, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.24365639, 15.46410785, 0.00244313)>
# 60847.28798240486
# <SkyCoord (GCRS: obstime=60847.28798240486, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.79399764, 23.43584233, 1.01621667)>
# <SkyCoord (GCRS: obstime=60847.28798240486, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.31226508, 15.49373799, 0.00244305)>
# 60847.29285795935
# <SkyCoord (GCRS: obstime=60847.29285795935, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.79906995, 23.43584906, 1.01621701)>
# <SkyCoord (GCRS: obstime=60847.29285795935, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.37937824, 15.52269353, 0.00244298)>
# 60847.29754140025
# <SkyCoord (GCRS: obstime=60847.29754140025, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.8039424, 23.43585538, 1.01621735)>
# <SkyCoord (GCRS: obstime=60847.29754140025, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.44386901, 15.55049085, 0.00244291)>
# 60847.30215201615
# <SkyCoord (GCRS: obstime=60847.30215201615, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.80873909, 23.43586144, 1.01621767)>
# <SkyCoord (GCRS: obstime=60847.30215201615, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.50737817, 15.57783937, 0.00244284)>
# 60847.30846961167
# <SkyCoord (GCRS: obstime=60847.30846961167, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.81531164, 23.43586952, 1.01621812)>
# <SkyCoord (GCRS: obstime=60847.30846961167, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.59443435, 15.61528628, 0.00244274)>
# 60847.313429730166
# <SkyCoord (GCRS: obstime=60847.313429730166, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.82047193, 23.43587567, 1.01621848)>
# <SkyCoord (GCRS: obstime=60847.313429730166, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.66281227, 15.64466511, 0.00244267)>
# 60847.318439466
# <SkyCoord (GCRS: obstime=60847.318439466, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.82568384, 23.4358817, 1.01621883)>
# <SkyCoord (GCRS: obstime=60847.318439466, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.73189896, 15.67431832, 0.00244259)>
# 60847.32325156351
# <SkyCoord (GCRS: obstime=60847.32325156351, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.83069013, 23.43588734, 1.01621917)>
# <SkyCoord (GCRS: obstime=60847.32325156351, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.79828359, 15.70278318, 0.00244252)>
# 60847.32802777597
# <SkyCoord (GCRS: obstime=60847.32802777597, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.83565909, 23.43589277, 1.01621951)>
# <SkyCoord (GCRS: obstime=60847.32802777597, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.86419592, 15.73101779, 0.00244245)>
# 60847.33327969511
# <SkyCoord (GCRS: obstime=60847.33327969511, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.84112295, 23.43589857, 1.01621988)>
# <SkyCoord (GCRS: obstime=60847.33327969511, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (29.93669927, 15.76204379, 0.00244237)>
# 60847.340710930366
# <SkyCoord (GCRS: obstime=60847.340710930366, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.84885408, 23.43590644, 1.01622041)>
# <SkyCoord (GCRS: obstime=60847.340710930366, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (30.03933528, 15.80590698, 0.00244226)>
# 60847.35829598474
# <SkyCoord (GCRS: obstime=60847.35829598474, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.86714877, 23.43592356, 1.01622165)>
# <SkyCoord (GCRS: obstime=60847.35829598474, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (30.28242968, 15.90952867, 0.00244199)>
# 60847.36294129422
# <SkyCoord (GCRS: obstime=60847.36294129422, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.87198154, 23.43592772, 1.01622198)>
# <SkyCoord (GCRS: obstime=60847.36294129422, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (30.34669772, 15.93686034, 0.00244192)>
# 60847.367649566055
# <SkyCoord (GCRS: obstime=60847.367649566055, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (89.87687981, 23.43593179, 1.01622231)>
# <SkyCoord (GCRS: obstime=60847.367649566055, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (30.41185892, 15.96454476, 0.00244185)>
# 60848.059114986514
# <SkyCoord (GCRS: obstime=60848.059114986514, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (90.59623352, 23.43486882, 1.01626982)>
# <SkyCoord (GCRS: obstime=60848.059114986514, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (40.23263214, 19.81055129, 0.00243328)>
# 60848.06396794368
# <SkyCoord (GCRS: obstime=60848.06396794368, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (90.60128205, 23.4348497, 1.01627014)>
# <SkyCoord (GCRS: obstime=60848.06396794368, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (40.30337483, 19.83581358, 0.00243323)>
# 60848.06855462841
# <SkyCoord (GCRS: obstime=60848.06855462841, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (90.60605358, 23.43483148, 1.01627045)>
# <SkyCoord (GCRS: obstime=60848.06855462841, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (40.37025977, 19.85966517, 0.00243319)>
# 60848.080512455155
# <SkyCoord (GCRS: obstime=60848.080512455155, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (90.6184933, 23.4347833, 1.01627124)>
# <SkyCoord (GCRS: obstime=60848.080512455155, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (40.54474239, 19.92173532, 0.00243307)>
# 60848.08525728781
# <SkyCoord (GCRS: obstime=60848.08525728781, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (90.62342934, 23.43476391, 1.01627156)>
# <SkyCoord (GCRS: obstime=60848.08525728781, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (40.61402015, 19.94631928, 0.00243303)>
# 60848.090119279266
# <SkyCoord (GCRS: obstime=60848.090119279266, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (90.62848726, 23.43474388, 1.01627188)>
# <SkyCoord (GCRS: obstime=60848.090119279266, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (40.68503417, 19.97148349, 0.00243298)>
# 60848.096261413324
# <SkyCoord (GCRS: obstime=60848.096261413324, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (90.6348769, 23.43471834, 1.01627229)>
# <SkyCoord (GCRS: obstime=60848.096261413324, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (40.77478305, 20.0032345, 0.00243292)>
# 60848.10087899952
# <SkyCoord (GCRS: obstime=60848.10087899952, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (90.63968056, 23.43469897, 1.0162726)>
# <SkyCoord (GCRS: obstime=60848.10087899952, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (40.84228254, 20.02707593, 0.00243288)>
# 60848.105465834575
# <SkyCoord (GCRS: obstime=60848.105465834575, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (90
obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (93.70901455, 23.39223944, 1.01644281)>
# <SkyCoord (GCRS: obstime=60851.052314099325, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (87.88515147, 28.4011169, 0.00244422)>
# 60851.056847507396
# <SkyCoord (GCRS: obstime=60851.056847507396, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (93.71372666, 23.39212807, 1.01644303)>
# <SkyCoord (GCRS: obstime=60851.056847507396, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (87.96033795, 28.4013856, 0.0024443)>
# 60851.06145311161
# <SkyCoord (GCRS: obstime=60851.06145311161, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (93.71851382, 23.39201478, 1.01644325)>
# <SkyCoord (GCRS: obstime=60851.06145311161, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (88.03671716, 28.40161621, 0.00244439)>
# 60851.06603854903
# <SkyCoord (GCRS: obstime=60851.06603854903, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (93.72328, 23.39190185, 1.01644348)>
# <SkyCoord (GCRS: obstime=60851.06603854903, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (88.11275721, 28.40180339, 0.00244447)>
# 60851.07246186539
# <SkyCoord (GCRS: obstime=60851.07246186539, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (93.72995648, 23.3917434, 1.01644379)>
# <SkyCoord (GCRS: obstime=60851.07246186539, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (88.21926665, 28.40199444, 0.00244459)>
# 60851.081073030546
# <SkyCoord (GCRS: obstime=60851.081073030546, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (93.73890702, 23.39153054, 1.0164442)>
# <SkyCoord (GCRS: obstime=60851.081073030546, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (88.36203926, 28.40212032, 0.00244474)>
# 60856.05025227127
# <SkyCoord (GCRS: obstime=60856.05025227127, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.89561374, 23.1840008, 1.01660937)>
# <SkyCoord (GCRS: obstime=60856.05025227127, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (159.03726969, 10.12464546, 0.00260555)>
# 60856.07779165206
# <SkyCoord (GCRS: obstime=60856.07779165206, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.92413337, 23.18238201, 1.01660989)>
# <SkyCoord (GCRS: obstime=60856.07779165206, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (159.35598088, 9.96649908, 0.00260653)>
# 60856.082414876975
# <SkyCoord (GCRS: obstime=60856.082414876975, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.92892108, 23.18210975, 1.01660997)>
# <SkyCoord (GCRS: obstime=60856.082414876975, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (159.40942977, 9.93993241, 0.00260669)>
# 60856.087139580144
# <SkyCoord (GCRS: obstime=60856.087139580144, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.93381386, 23.18183137, 1.01661006)>
# <SkyCoord (GCRS: obstime=60856.087139580144, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (159.4640355, 9.91277748, 0.00260686)>
# 60856.09451625455
# <SkyCoord (GCRS: obstime=60856.09451625455, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.94145289, 23.18139642, 1.0166102)>
# <SkyCoord (GCRS: obstime=60856.09451625455, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (159.54925839, 9.87037018, 0.00260712)>
# 60856.10105368282
# <SkyCoord (GCRS: obstime=60856.10105368282, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.94822279, 23.18101065, 1.01661032)>
# <SkyCoord (GCRS: obstime=60856.10105368282, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (159.62475194, 9.83277712, 0.00260735)>
# 60856.11295224268
# <SkyCoord (GCRS: obstime=60856.11295224268, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.96054434, 23.18030778, 1.01661054)>
# <SkyCoord (GCRS: obstime=60856.11295224268, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (159.76207476, 9.76433027, 0.00260777)>
# 60856.12671258321
# <SkyCoord (GCRS: obstime=60856.12671258321, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.97479368, 23.17949374, 1.01661079)>
# <SkyCoord (GCRS: obstime=60856.12671258321, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (159.9207556, 9.68513378, 0.00260826)>
# 60856.13813688593
# <SkyCoord (GCRS: obstime=60856.13813688593, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.98662381, 23.17881692, 1.016611)>
# <SkyCoord (GCRS: obstime=60856.13813688593, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (160.05239324, 9.61935029, 0.00260866)>
# 60856.14954639761
# <SkyCoord (GCRS: obstime=60856.14954639761, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (98.99843849, 23.1781401, 1.01661121)>
# <SkyCoord (GCRS: obstime=60856.14954639761, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (160.18376623, 9.5536235, 0.00260906)>
# 60856.156080781184
# <SkyCoord (GCRS: obstime=60856.156080781184, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (99.00520486, 23.17775207, 1.01661133)>
# <SkyCoord (GCRS: obstime=60856.156080781184, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (160.25896311, 9.5159682, 0.00260929)>
# 60856.1655911754
# <SkyCoord (GCRS: obstime=60856.1655911754, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (99.01505282, 23.17718681, 1.0166115)>
# <SkyCoord (GCRS: obstime=60856.1655911754, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (160.36835282, 9.46114693, 0.00260962)>
# 60856.171781440935
# <SkyCoord (GCRS: obstime=60856.171781440935, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (99.02146275, 23.17681856, 1.01661161)>
# <SkyCoord (GCRS: obstime=60856.171781440935, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (160.43951926, 9.42545376, 0.00260984)>
# 60856.2677262653
# <SkyCoord (GCRS: obstime=60856.2677262653, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (99.12080712, 23.17107774, 1.01661333)>
# <SkyCoord (GCRS: obstime=60856.2677262653, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (161.53910245, 8.87124232, 0.00261319)>
# 60856.27890331989
# <SkyCoord (GCRS: obstime=60856.27890331989, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (99.13237958, 23.17040492, 1.01661352)>
# <SkyCoord (GCRS: obstime=60856.27890331989, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (161.66678378, 8.80656409, 0.00261358)>
# 60857.29850339185
# <SkyCoord (GCRS: obstime=60857.29850339185, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.18747859, 23.10548, 1.01662866)>
# <SkyCoord (GCRS: obstime=60857.29850339185, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.01177984, 2.85027482, 0.00264655)>
# 60857.30519774354
# <SkyCoord (GCRS: obstime=60857.30519774354, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.19440218, 23.10503056, 1.01662874)>
# <SkyCoord (GCRS: obstime=60857.30519774354, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.08465564, 2.81105264, 0.00264674)>
# 60857.30982122192
# <SkyCoord (GCRS: obstime=60857.30982122192, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.19918395, 23.10471998, 1.01662879)>
# <SkyCoord (GCRS: obstime=60857.30982122192, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.13497804, 2.78396461, 0.00264688)>
# 60857.31460679413
# <SkyCoord (GCRS: obstime=60857.31460679413, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.20413333, 23.10439837, 1.01662885)>
# <SkyCoord (GCRS: obstime=60857.31460679413, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.18705652, 2.7559277, 0.00264702)>
# 60857.3377865843
# <SkyCoord (GCRS: obstime=60857.3377865843, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.22810621, 23.10283836, 1.01662913)>
# <SkyCoord (GCRS: obstime=60857.3377865843, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.43919152, 2.62013796, 0.0026477)>
# 60857.34280574312
# <SkyCoord (GCRS: obstime=60857.34280574312, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.23329701, 23.1025001, 1.01662919)>
# <SkyCoord (GCRS: obstime=60857.34280574312, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.49376152, 2.59073798, 0.00264785)>
# 60857.348160373665
# <SkyCoord (GCRS: obstime=60857.348160373665, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.23883473, 23.10213904, 1.01662926)>
# <SkyCoord (GCRS: obstime=60857.348160373665, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.55196908, 2.5593741, 0.00264801)>
# 60857.352779073495
# <SkyCoord (GCRS: obstime=60857.352779073495, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.24361133, 23.10182744, 1.01662931)>
# <SkyCoord (GCRS: obstime=60857.352779073495, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.60216859, 2.53232181, 0.00264814)>
# 60857.35960499165
# <SkyCoord (GCRS: obstime=60857.35960499165, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.25067056, 23.10136668, 1.01662939)>
# <SkyCoord (GCRS: obstime=60857.35960499165, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.67634416, 2.49234325, 0.00264834)>
# 60857.36425344927
# <SkyCoord (GCRS: obstime=60857.36425344927, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.25547787, 23.10105272, 1.01662945)>
# <SkyCoord (GCRS: obstime=60857.36425344927, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.72684852, 2.465119, 0.00264848)>
# 60857.36880946137
# <SkyCoord (GCRS: obstime=60857.36880946137, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.26018955, 23.10074486, 1.0166295)>
# <SkyCoord (GCRS: obstime=60857.36880946137, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (173.77634121, 2.43843713, 0.00264861)>
# 60857.37335579303
# <SkyCoord (GCRS: obstime=60857.37335579303, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (100.2648912, 23.10043752, 1.01662955)>
# <SkyCoord (GCRS: obstime=60857.37335579303, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
# ...
#     (116.66449473, 25.4380118, 0.00250162)>
# 60880.242004396954
# <SkyCoord (GCRS: obstime=60880.242004396954, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.47632653, 19.8789504, 1.01582036)>
# <SkyCoord (GCRS: obstime=60880.242004396954, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (116.73802714, 25.42235789, 0.00250173)>
# 60880.246783329516
# <SkyCoord (GCRS: obstime=60880.246783329516, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.4810636, 19.87794855, 1.01581994)>
# <SkyCoord (GCRS: obstime=60880.246783329516, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (116.80979973, 25.40703933, 0.00250184)>
# 60880.25173269177
# <SkyCoord (GCRS: obstime=60880.25173269177, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.48596955, 19.87691084, 1.0158195)>
# <SkyCoord (GCRS: obstime=60880.25173269177, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (116.8841062, 25.39113906, 0.00250195)>
# 60880.256562647475
# <SkyCoord (GCRS: obstime=60880.256562647475, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.49075709, 19.87589804, 1.01581908)>
# <SkyCoord (GCRS: obstime=60880.256562647475, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (116.95659473, 25.3755877, 0.00250206)>
# 60880.261415803485
# <SkyCoord (GCRS: obstime=60880.261415803485, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.49556756, 19.87488024, 1.01581865)>
# <SkyCoord (GCRS: obstime=60880.261415803485, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.02940629, 25.35992719, 0.00250217)>
# 60880.266009588755
# <SkyCoord (GCRS: obstime=60880.266009588755, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.50012089, 19.87391672, 1.01581824)>
# <SkyCoord (GCRS: obstime=60880.266009588755, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.09830328, 25.34507184, 0.00250228)>
# 60880.27073743648
# <SkyCoord (GCRS: obstime=60880.27073743648, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.50480705, 19.87292495, 1.01581782)>
# <SkyCoord (GCRS: obstime=60880.27073743648, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.16918727, 25.32975072, 0.00250239)>
# 60880.27531439211
# <SkyCoord (GCRS: obstime=60880.27531439211, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.5093436, 19.87196472, 1.01581742)>
# <SkyCoord (GCRS: obstime=60880.27531439211, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.23778608, 25.31488747, 0.0025025)>
# 60880.279924879964
# <SkyCoord (GCRS: obstime=60880.279924879964, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.51391333, 19.87099734, 1.01581701)>
# <SkyCoord (GCRS: obstime=60880.279924879964, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.3068647, 25.29988442, 0.0025026)>
# 60880.298059507666
# <SkyCoord (GCRS: obstime=60880.298059507666, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.53188714, 19.86719116, 1.0158154)>
# <SkyCoord (GCRS: obstime=60880.298059507666, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.57835234, 25.24057207, 0.00250302)>
# 60880.304752515956
# <SkyCoord (GCRS: obstime=60880.304752515956, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.5385206, 19.86578594, 1.0158148)>
# <SkyCoord (GCRS: obstime=60880.304752515956, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.67846149, 25.21856084, 0.00250318)>
# 60880.31108771295
# <SkyCoord (GCRS: obstime=60880.31108771295, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.54479932, 19.86445562, 1.01581424)>
# <SkyCoord (GCRS: obstime=60880.31108771295, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.77317409, 25.19766661, 0.00250333)>
# 60880.316645601495
# <SkyCoord (GCRS: obstime=60880.316645601495, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.55030759, 19.86328834, 1.01581375)>
# <SkyCoord (GCRS: obstime=60880.316645601495, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.85622994, 25.17928828, 0.00250346)>
# 60880.321176646714
# <SkyCoord (GCRS: obstime=60880.321176646714, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.55479812, 19.86233659, 1.01581334)>
# <SkyCoord (GCRS: obstime=60880.321176646714, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.92391607, 25.16427244, 0.00250356)>
# 60880.32575461899
# <SkyCoord (GCRS: obstime=60880.32575461899, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.55933511, 19.86137487, 1.01581294)>
# <SkyCoord (GCRS: obstime=60880.32575461899, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (117.99228057, 25.14907104, 0.00250367)>
# 60880.33047399069
# <SkyCoord (GCRS: obstime=60880.33047399069, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.56401218, 19.86038333, 1.01581252)>
# <SkyCoord (GCRS: obstime=60880.33047399069, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (118.06273279, 25.13336856, 0.00250378)>
# 60880.33644893539
# <SkyCoord (GCRS: obstime=60880.33644893539, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.56993349, 19.85912781, 1.01581199)>
# <SkyCoord (GCRS: obstime=60880.33644893539, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (118.15189382, 25.11344257, 0.00250392)>
# 60880.34394381333
# <SkyCoord (GCRS: obstime=60880.34394381333, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.57736097, 19.85755263, 1.01581132)>
# <SkyCoord (GCRS: obstime=60880.34394381333, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (118.26368102, 25.08837531, 0.0025041)>
# 60880.353985734
# <SkyCoord (GCRS: obstime=60880.353985734, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (123.58731237, 19.85544165, 1.01581042)>
# <SkyCoord (GCRS: obstime=60880.353985734, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (118.41336165, 25.05466322, 0.00250434)>
# 60885.10337002792
# <SkyCoord (GCRS: obstime=60885.10337002792, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.26559493, 18.79606672, 1.01532142)>
# <SkyCoord (GCRS: obstime=60885.10337002792, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (177.81118524, 0.03336205, 0.00264552)>
# 60885.109684183066
# <SkyCoord (GCRS: obstime=60885.109684183066, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.27177626, 18.79457924, 1.01532069)>
# <SkyCoord (GCRS: obstime=60885.109684183066, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (177.8799678, -0.00401933, 0.00264569)>
# 60885.11598366112
# <SkyCoord (GCRS: obstime=60885.11598366112, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.27794311, 18.79309501, 1.01531995)>
# <SkyCoord (GCRS: obstime=60885.11598366112, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (177.94858067, -0.04130856, 0.00264587)>
# 60885.12232769444
# <SkyCoord (GCRS: obstime=60885.12232769444, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.28415348, 18.79160008, 1.01531922)>
# <SkyCoord (GCRS: obstime=60885.12232769444, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (178.01766901, -0.07885618, 0.00264604)>
# 60885.12857021525
# <SkyCoord (GCRS: obstime=60885.12857021525, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.29026438, 18.79012887, 1.01531849)>
# <SkyCoord (GCRS: obstime=60885.12857021525, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (178.0856423, -0.1157977, 0.00264621)>
# 60885.134809457835
# <SkyCoord (GCRS: obstime=60885.134809457835, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.29637196, 18.78865824, 1.01531777)>
# <SkyCoord (GCRS: obstime=60885.134809457835, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (178.15357049, -0.15271454, 0.00264638)>
# 60885.3014188731
# <SkyCoord (GCRS: obstime=60885.3014188731, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.45942838, 18.74931322, 1.01529831)>
# <SkyCoord (GCRS: obstime=60885.3014188731, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (179.9642527, -1.13640637, 0.00265087)>
# 60885.3061691445
# <SkyCoord (GCRS: obstime=60885.3061691445, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.4640763, 18.74818935, 1.01529776)>
# <SkyCoord (GCRS: obstime=60885.3061691445, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.01579307, -1.16438856, 0.00265099)>
# 60885.318699926254
# <SkyCoord (GCRS: obstime=60885.318699926254, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.4763368, 18.74522413, 1.01529629)>
# <SkyCoord (GCRS: obstime=60885.318699926254, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.15173115, -1.23818472, 0.00265132)>
# 60885.33033064512
# <SkyCoord (GCRS: obstime=60885.33033064512, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.48771628, 18.74247118, 1.01529492)>
# <SkyCoord (GCRS: obstime=60885.33033064512, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.27787856, -1.30665624, 0.00265163)>
# 60885.335465451186
# <SkyCoord (GCRS: obstime=60885.335465451186, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.49274006, 18.74125557, 1.01529432)>
# <SkyCoord (GCRS: obstime=60885.335465451186, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.33356294, -1.33687806, 0.00265177)>
# 60885.34380562395
# <SkyCoord (GCRS: obstime=60885.34380562395, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.50089975, 18.73928084, 1.01529334)>
# <SkyCoord (GCRS: obstime=60885.34380562395, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.4239976, -1.38595586, 0.00265199)>
# 60885.34840543009
# <SkyCoord (GCRS: obstime=60885.34840543009, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.50539994, 18.73819157, 1.0152928)>
# <SkyCoord (GCRS: obstime=60885.34840543009, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.47386909, -1.41301823, 0.00265211)>
# 60885.353026653116
# <SkyCoord (GCRS: obstime=60885.353026653116, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.50992103, 18.73709712, 1.01529226)>
# <SkyCoord (GCRS: obstime=60885.353026653116, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.52396893, -1.44020285, 0.00265223)>
# 60885.3576117639
# <SkyCoord (GCRS: obstime=60885.3576117639, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.51440673, 18.73601112, 1.01529172)>
# <SkyCoord (GCRS: obstime=60885.3576117639, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.5736735, -1.4671713, 0.00265235)>
# 60885.36218488143
# <SkyCoord (GCRS: obstime=60885.36218488143, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.51888065, 18.73492785, 1.01529118)>
# <SkyCoord (GCRS: obstime=60885.36218488143, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.62324433, -1.49406548, 0.00265247)>
# 60885.36838365379
# <SkyCoord (GCRS: obstime=60885.36838365379, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.52494487, 18.73345933, 1.01529045)>
# <SkyCoord (GCRS: obstime=60885.36838365379, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.69043075, -1.53051405, 0.00265263)>
# 60885.37294378239
# <SkyCoord (GCRS: obstime=60885.37294378239, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.52940595, 18.73237889, 1.01528992)>
# <SkyCoord (GCRS: obstime=60885.37294378239, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.73985217, -1.55732304, 0.00265275)>
# 60885.37746795875
# <SkyCoord (GCRS: obstime=60885.37746795875, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.53383181, 18.73130686, 1.01528939)>
# <SkyCoord (GCRS: obstime=60885.37746795875, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.78888039, -1.58391695, 0.00265287)>
# 60885.38203090765
# <SkyCoord (GCRS: obstime=60885.38203090765, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.53829554, 18.73022553, 1.01528885)>
# <SkyCoord (GCRS: obstime=60885.38203090765, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.83832521, -1.61073502, 0.00265299)>
# 60885.38658056854
# <SkyCoord (GCRS: obstime=60885.38658056854, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.54274622, 18.72914725, 1.01528831)>
# <SkyCoord (GCRS: obstime=60885.38658056854, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.88762249, -1.6374712, 0.00265311)>
# 60885.39259724862
# <SkyCoord (GCRS: obstime=60885.39259724862, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (128.54863192, 18.72772112, 1.01528761)>
# <SkyCoord (GCRS: obstime=60885.39259724862, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (180.95281009, -1.67282253, 0.00265326)>

# %%
framerate = 15

# %%
! cd ../results/sv-viz && ffmpeg -framerate {framerate} -i "frame_%05d.png" -c:v libx264 -pix_fmt yuv420p ../sv-viz.mp4 -y
# Out:
# ffmpeg version 5.1.6 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 11 (GCC)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --docdir=/usr/share/doc/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -flto=auto -ffat-lto-objects -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -fstack-protector-strong -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 -m64 -march=x86-64-v2 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection' --extra-ldflags='-Wl,-z,relro -Wl,--as-needed -Wl,-z,now -specs=/usr/lib/rpm/redhat/redhat-hardened-ld -specs=/usr/lib/rpm/redhat/redhat-annobin-cc1 ' --extra-cflags=' -I/usr/include/rav1e' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --disable-crystalhd --enable-fontconfig --enable-frei0r --enable-gcrypt --enable-gnutls --enable-ladspa --enable-libaom --enable-libdav1d --enable-libass --enable-libbluray --enable-libcdio --enable-libdrm --enable-libjack --enable-libjxl --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-nvenc --enable-openal --enable-opencl --enable-opengl --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libvorbis --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-version3 --enable-vapoursynth --enable-libvpx --enable-vulkan --enable-libshaderc --enable-libx264 --enable-libx265 --enable-libxvid --enable-libxml2 --enable-libzimg --enable-libzvbi --enable-lv2 --enable-avfilter --enable-libmodplug --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-lto --enable-libmfx --enable-runtime-cpudetect
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, image2, from 'frame_%05d.png':
#   Duration: 00:01:21.27, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 15 fps, 15 tbr, 15 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56441832d300] using SAR=1/1
# [libx264 @ 0x56441832d300] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x56441832d300] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x56441832d300] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=15 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../sv-viz.mp4':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 640x480 [SAR 1:1 DAR 4:3], q=2-31, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc59.37.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1219 fps=195 q=-1.0 Lsize=     900kB time=00:01:21.06 bitrate=  90.9kbits/s speed=12.9x
# video:884kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.710204%
# [libx264 @ 0x56441832d300] frame I:5     Avg QP:11.93  size: 16410
# [libx264 @ 0x56441832d300] frame P:307   Avg QP:17.81  size:   880
# [libx264 @ 0x56441832d300] frame B:907   Avg QP:24.32  size:   609
# [libx264 @ 0x56441832d300] consecutive B-frames:  0.7%  0.2%  0.0% 99.1%
# [libx264 @ 0x56441832d300] mb I  I16..4: 41.8% 37.1% 21.1%
# [libx264 @ 0x56441832d300] mb P  I16..4:  0.2%  0.2%  0.3%  P16..4:  0.8%  0.4%  0.4%  0.0%  0.0%    skip:97.9%
# [libx264 @ 0x56441832d300] mb B  I16..4:  0.3%  0.1%  0.1%  B16..8:  1.9%  0.3%  0.3%  direct: 0.1%  skip:96.7%  L0:54.6% L1:41.6% BI: 3.8%
# [libx264 @ 0x56441832d300] 8x8 transform intra:30.3% inter:21.0%
# [libx264 @ 0x56441832d300] coded y,uvDC,uvAC intra: 24.7% 8.8% 8.5% inter: 0.6% 0.3% 0.3%
# [libx264 @ 0x56441832d300] i16 v,h,dc,p: 78% 16%  7%  0%
# [libx264 @ 0x56441832d300] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34%  9% 49%  1%  1%  1%  2%  2%  2%
# [libx264 @ 0x56441832d300] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 17% 21%  6%  5%  4%  5%  6%  5%
# [libx264 @ 0x56441832d300] i8c dc,h,v,p: 94%  3%  2%  1%
# [libx264 @ 0x56441832d300] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56441832d300] ref P L0: 47.3%  8.7% 26.3% 17.6%
# [libx264 @ 0x56441832d300] ref B L0: 62.7% 31.9%  5.4%
# [libx264 @ 0x56441832d300] ref B L1: 88.8% 11.2%
# [libx264 @ 0x56441832d300] kb/s:89.08
